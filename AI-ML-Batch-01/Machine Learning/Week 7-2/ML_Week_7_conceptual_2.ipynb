# %%
import numpy as np
import pandas as pd

data = {
    'Room_Size' : [500,1000,1500,2000,2500],
    'Bath_Size' : [40,60,80,100,120]
}

df = pd.DataFrame(data)

df
# Out:
#    Room_Size  Bath_Size
# 0        500         40
# 1       1000         60
# 2       1500         80
# 3       2000        100
# 4       2500        120

# %%
covariance_matrix = np.cov(df,rowvar=False)

# print(type(covariance_matrix))


eigen_values,eigen_vector = np.linalg.eig(covariance_matrix)

# print(eigen_values)
# print(eigen_vector)


selected_vector = eigen_vector[::,0:1]

print(selected_vector)



df['house_size'] = np.dot(df,selected_vector)

df
# Out:
# [[ 0.99920096]
#  [-0.03996804]]
#    Room_Size  Bath_Size   house_size
# 0        500         40   498.001758
# 1       1000         60   996.802876
# 2       1500         80  1495.603995
# 3       2000        100  1994.405114
# 4       2500        120  2493.206232
